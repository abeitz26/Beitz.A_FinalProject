# %%
import pandas as pd
import numpy as np
import datetime as datetime
import matplotlib.pyplot as plt

# %%
#data import
file_sst = 'sst.csv'
file_diatom ='diatom_data.csv'
file_so4 = 'so4_data.csv'

dia_df = pd.read_csv(file_diatom)
display(dia_df)

sst_df = pd.read_csv(file_sst)
display(sst_df)

so4_df = pd.read_csv(file_so4)
display(so4_df)
# Out:
#     Depth sed [m]  Age [ka BP]  Age [a AD/CE]  A. baicalensis [%]
# 0          0.0010       -0.063           2013               33.44  \
# 1          0.0030       -0.061           2011               33.66
# 2          0.0050       -0.059           2009               34.05
# 3          0.0070       -0.056           2006               27.50
# 4          0.0090       -0.053           2003               25.40
# 5          0.0110       -0.048           1998               33.77
# 6          0.0127       -0.044           1994               33.85
# 7          0.0130       -0.043           1993               31.68
# 8          0.0140       -0.040           1990               36.20
# 9          0.0150       -0.037           1987               33.39
# 10         0.0155       -0.036           1986               37.32
# 11         0.0170       -0.031           1981               26.92
# 12         0.0187       -0.025           1975               40.60
# ...

# %%
#Cutting the diatom measurements down to match the dates of the sulfate measurements
dia_df_short = dia_df.loc[dia_df["Age [a AD/CE]"] > 1960]

#Averaging the sulfate concetration measurement to be from 0-200m, the photic layer, so only the sulfate concentration affecting the diatoms is shown
#separating the orginal df to only include up 200m
so4_df = so4_df.loc[so4_df['Depth water [m]'] < 201]
display(so4_df)

#index the specifc dates from the short df and then average them into a numpy array, then create new data frame with simplified dates and averages
so4_df.tonumpy()


#splitting the array into the 200m chunks per year
#so4_avg1 = so4_df.loc[so4_df['Date/Time'] == 1967].mean().round(2)
#print(so4_avg1)
#so4_df2 = so4_df.loc[so4_df['Date/Time'] == 1981]
#so4_df3 = so4_df.loc[so4_df['Date/Time'] == 1983]
#so4_df4 = so4_df.loc[so4_df['Date/Time'] == 1986]
#so4_df5 = so4_df.loc[so4_df['Date/Time'] == 2004]

#averaging them and making a new data frame
so4_avg1 = so4_df1.loc[so4_df1['[SO4]2- [mg/l]']]


#splitting data frome into 200m chunks
#so4_df_200m = so4_df.loc[so4_df["Depth water [m]"] < 201]
#creating a function to average all the depths
#def avg_depth(num):
    #so4_df_avg = so4_df.loc['Date/Time' = num]
    #avg = so4_df_avg.mean()
# Out:
#     Depth water [m]  Date/Time  Date/time end  [SO4]2- [mg/l]
# 0                 0       1967           1968             3.9
# 1                10       1967           1968             4.4
# 2                25       1967           1968             4.1
# 3                50       1967           1968             3.8
# 4               100       1967           1968             3.9
# 5               200       1967           1968             3.8
# 17                0       1981           1982             4.8
# 18               10       1981           1982             4.8
# 19               25       1981           1982             4.9
# 20               50       1981           1982             5.3
# 21              100       1981           1982             5.2
# 22              200       1981           1982             4.9
# 28                0       1983           1984             4.6
# 29               10       1983           1984             4.7
# ...

# %%
#indexing all needed variable for conciseness
so4_conc = so4_df['[SO4]2- [mg/l]']
dates_so4 = so4_df['Date/Time']

dates_dia_tot = dia_df_short['Age [a AD/CE]'].values
dates_dia = dates_dia_tot[1950:2005]
dia_tot = dia_df_short['TDVA [10**6 #/g]'].values
dia_need = dia_tot[1950:2005]

dia_ab = dia_df_short['A. baicalensis [%]'].values
dia_as = dia_df_short['A. skvortzowii [%]'].values
dia_ss = dia_df_short['Synedra spp. [%]'].values
dia_cm = dia_df_short['C. minuta [%]'].values
dia_ci = dia_df_short['C. inconspicua [%]'].values
dia_sm = dia_df_short['S. meyeri [%]'].values

# %%
#two y axes https://www.statology.org/matplotlib-two-y-axes/

fig,ax = plt.subplots(figsize=(18,6))

ax2 = ax.twinx()

list1 = ax2.plot(dates_dia_tot, dia_tot, c='purple', linestyle='-', linewidth=3.5, marker=None, label= 'Total diatom value')
list2 = ax.plot(dates_so4, so4_conc, c='orange', linestyle='-', linewidth=3.5, marker=None,label = 'SO4 Concentration')

ax2.scatter(dates_dia_tot, dia_tot, s=20, c='purple')
ax.scatter(dates_so4, so4_conc, s=20, c='orange')

ax.grid()

ax.set_title('Sulfate Concentrations and Diatom assemblage over Time', fontsize=20)
ax.set_xlabel('Time', fontsize=17)
ax.set_ylabel('SO4^2- [mg/l]', fontsize=17)
ax2.set_ylabel('Diatom Assemblage Total,[10^6 #/g]', fontsize=17)

fig.legend(fontsize= 13)

# %%
fig,ax = plt.subplots(figsize=(14,3))

ax.plot(dates_dia_tot, dia_ab, c='green', linestyle='-', linewidth=2, marker=None, label= 'A. baicalensis')
ax.plot(dates_dia_tot, dia_as, c='red', linestyle='-', linewidth=2, marker=None, label= 'A. skvortzowii')
ax.plot(dates_dia_tot, dia_ss, c='blue', linestyle='-', linewidth=2, marker=None, label= 'Synedra spp.')
ax.plot(dates_dia_tot, dia_cm, c='k', linestyle='-', linewidth=2, marker=None, label= 'C. minuta')
ax.plot(dates_dia_tot, dia_ci, c='pink', linestyle='-', linewidth=2, marker=None, label= 'C. inconspicua')
ax.plot(dates_dia_tot, dia_sm, c='orange', linestyle='-', linewidth=2, marker=None, label= 'S. meyeri')

ax.grid()

ax.set_title('Comparison of Diatom Species Poputlation over Time', fontsize=18)
ax.set_xlabel('Time', fontsize=14)
ax.set_ylabel('Percent Species', fontsize=14)

ax.legend(loc='upper center',shadow=True, fontsize='large')
