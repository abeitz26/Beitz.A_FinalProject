# %%
import pandas as pd
import numpy as np
import datetime as datetime
import matplotlib.pyplot as plt

# %%
#data import
file_sst = 'sst.csv'
file_diatom ='diatom_assembl.tab'
file_so4 = 'baikal_so4.tab'
     
diatom_df = pd.read_table(file_diatom, sep='\t', header=0)
so4_df = pd.read_table(file_diatom, sep='\t', header=0)
sst_df = pd.read
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 6
#       3 file_diatom ='diatom_assembl.tab'
#       4 file_so4 = 'baikal_so4.tab'
# ----> 6 pd.read_table(file_diatom, sep='\t', header=0)
#
# ...

# %%
pro_df = pd.read_csv(file_diatom, index_col=0)

with open(file_diatom) as f:
    reader = csv.reader(f, dialect=csv.excel_tab)
    header = reader.next()
    data = [row for row in reader]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pro_df = pd.read_csv(file_diatom, index_col=0)
#       3 with open(file_diatom) as f:
#       4     reader = csv.reader(f, dialect=csv.excel_tab)
#
# ...

# %%
#index so4 differently only need specific depths/should i average the photosynthetic layer depths?
so4_conc = so4_df['[SO4]2- [mg/l]']


dates_dia = diatom_df['Age [a AD/CE]'].values
diatom_tot = diatom_df['TDVA [106 #/g]'].values

diatom_ab = diatom_df['A. baicalensis [%]'].values
diatom_as = diatom_df['A. skvortzowii [%]'].values
diatom_ss = diatom_df['Synedra spp. [%]'].values
diatom_cm = diatom_df['C. minuta [%]'].values
diatom_ci = diatom_df['C. inconspicua [%]'].values
diatom_cm = diatom_df['S. meyeri [%]'].values

# %%
#two y axes https://www.statology.org/matplotlib-two-y-axes/

fig,ax = plt.subplots(figsize=(14,3))

ax2 = ax.twinx()

ax2.plot(dates_dia, diatom_tot, c='green', linestyle='-', linewidth=2, marker=None, label= 'Total diatom value')
ax.plot(dates_so4, so4_conc, c='k', linestyle='-', linewidth=2, marker=None,label = 'SO4 Concetration')

ax.scatter(datetime_list, depths, s=35, c='k')

ax.grid()

ax.set_title('Sulfate Concentrations and Diatom assemblage over Time', fontsize=18)
ax.set_xlabel('Time', fontsize=14)
ax.set_ylabel('Seafloor depth (m)', fontsize=14)
ax2.set_ylabel('Diatom Assemblage Total', fontsize=14)

ax.legend(loc='upper center',shadow=True, fontsize='large')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 fig,ax = plt.subplots(figsize=(14,3))
# ----> 3 ax.plot(dates_dia, diatom_data, c='green', linestyle='-', linewidth=2, marker=None, label= 'A. baicalensis')
#       4 ax.plot(dates_dia, diatom_data, c='green', linestyle='-', linewidth=2, marker=None, label= 'A. skvortzowii')
#       5 ax.plot(dates_dia, diatom_data, c='green', linestyle='-', linewidth=2, marker=None, label= 'Synedra spp.')
#
# NameError: name 'dates_dia' is not defined

# %%
fig,ax = plt.subplots(figsize=(14,3))

ax.plot(dates_dia, diatom_ab, c='green', linestyle='-', linewidth=2, marker=None, label= 'A. baicalensis')
ax.plot(dates_dia, diatom_as, c='red', linestyle='-', linewidth=2, marker=None, label= 'A. skvortzowii')
ax.plot(dates_dia, diatom_ss, c='blue', linestyle='-', linewidth=2, marker=None, label= 'Synedra spp.')
ax.plot(dates_dia, diatom_cm, c='k', linestyle='-', linewidth=2, marker=None, label= 'C. minuta')
ax.plot(dates_dia, diatom_ci, c='pink', linestyle='-', linewidth=2, marker=None, label= 'C. inconspicua')
ax.plot(dates_dia, diatom_sm, c='orange', linestyle='-', linewidth=2, marker=None, label= 'S. meyeri')

ax.scatter(datetime_list, depths, s=35, c='k')

ax.grid()
ax.set_title('Comparison of Diatom Species Poputlation over Time', fontsize=18)
ax.set_xlabel('Time', fontsize=14)
ax.set_ylabel('Percent Species', fontsize=14)

ax.legend(loc='upper center',shadow=True, fontsize='large')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 fig,ax = plt.subplots(figsize=(14,3))
# ----> 3 ax.plot(dates_dia, diatom_ab, c='green', linestyle='-', linewidth=2, marker=None, label= 'A. baicalensis')
#       4 ax.plot(dates_dia, diatom_as, c='red', linestyle='-', linewidth=2, marker=None, label= 'A. skvortzowii')
#       5 ax.plot(dates_dia, diatom_ss, c='blue', linestyle='-', linewidth=2, marker=None, label= 'Synedra spp.')
#
# NameError: name 'dates_dia' is not defined
